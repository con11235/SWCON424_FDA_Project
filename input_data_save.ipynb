# %%
# !pip install -U finance-datareader

# %%
import FinanceDataReader as fdr

# %%
df_spx = fdr.StockListing('NASDAQ')
# Out:
# 100%|██████████| 3193/3193 [00:35<00:00, 89.22it/s]

# %%
input_dir = '/content/drive/MyDrive/인연준/금융데이터분석/input/'

# %%
df_spx.to_csv(input_dir + 'NASDAQ_stock_list.csv', index=False)

# %%
import pandas_datareader.data as web

# %%
all_asset = df_spx['Symbol'].tolist()

# %%
all_data = web.get_data_yahoo(all_asset, start='2010-01-01', end='2020-11-01')['Adj Close']
all_data.to_csv(input_dir + 'all_asset_2010_2020.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'MRVI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'SHC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'OLMA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'TLS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'PRTC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ...

# %%
import pandas as pd
pd.read_csv(input_dir+'all_asset.csv')
# Out:
#            Date        AAPL        MSFT         AMZN  ...  SHC  RCHG  LSAQ  VSPR
# 0    2018-01-02   41.105534   82.383636  1189.010010  ...  NaN   NaN   NaN   NaN
# 1    2018-01-03   41.098373   82.767044  1204.199951  ...  NaN   NaN   NaN   NaN
# 2    2018-01-04   41.289268   83.495522  1209.589966  ...  NaN   NaN   NaN   NaN
# 3    2018-01-05   41.759361   84.530701  1229.140015  ...  NaN   NaN   NaN   NaN
# 4    2018-01-08   41.604263   84.616966  1246.869995  ...  NaN   NaN   NaN   NaN
# ..          ...         ...         ...          ...  ...  ...   ...   ...   ...
# 709  2020-10-26  114.851852  209.531433  3207.040039  ...  NaN   NaN   NaN   NaN
# 710  2020-10-27  116.399178  212.693161  3286.330078  ...  NaN   NaN   NaN   NaN
# 711  2020-10-28  111.008476  202.150757  3162.780029  ...  NaN   NaN   NaN   NaN
# 712  2020-10-29  115.121384  204.185425  3211.010010  ...  NaN   NaN   NaN   NaN
# 713  2020-10-30  108.672516  201.941315  3036.149902  ...  NaN   NaN   NaN   NaN
#
# ...
